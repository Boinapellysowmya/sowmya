# %%
import pandas as pd
d=pd.read_csv('/content/drive/MyDrive/Lung cancer/survey lung cancer.csv')

# %%
print(d)
# Out:
#     GENDER   AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M  69.0      1.0             2.0      2.0            1.0
# 1        M  74.0      2.0             1.0      1.0            1.0
# 2        F  59.0      1.0             1.0      1.0            2.0
# 3        M  63.0      2.0             2.0      2.0            1.0
# 4        F  63.0      1.0             2.0      1.0            1.0
# ..     ...   ...      ...             ...      ...            ...
# 305      M  70.0      2.0             1.0      1.0            1.0
# 306      M  58.0      2.0             1.0      1.0            1.0
# 307      M  67.0      2.0             1.0      2.0            1.0
# 308      M  62.0      1.0             1.0      1.0            2.0
# 309      M   NaN      NaN             NaN      NaN            NaN
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                1.0       2.0       1.0       2.0                2.0
# 1                2.0       2.0       2.0       1.0                1.0
# 2                1.0       2.0       1.0       2.0                1.0
# 3                1.0       1.0       1.0       1.0                2.0
# 4                1.0       1.0       1.0       2.0                1.0
# ..               ...       ...       ...       ...                ...
# 305              1.0       2.0       2.0       2.0                2.0
# 306              1.0       1.0       2.0       2.0                2.0
# 307              1.0       2.0       2.0       1.0                2.0
# 308              1.0       2.0       2.0       2.0                2.0
# 309              NaN       NaN       NaN       NaN                NaN
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0         2.0                  2.0                    2.0         2.0
# 1         1.0                  2.0                    2.0         2.0
# 2         2.0                  2.0                    1.0         2.0
# 3         1.0                  1.0                    2.0         2.0
# 4         2.0                  2.0                    1.0         1.0
# ..        ...                  ...                    ...         ...
# 305       2.0                  2.0                    1.0         2.0
# 306       2.0                  1.0                    1.0         2.0
# 307       2.0                  2.0                    1.0         2.0
# 308       1.0                  1.0                    2.0         1.0
# 309       NaN                  NaN                    NaN         NaN
#
#      LUNG_CANCER
# 0            1.0
# 1            1.0
# 2            0.0
# 3            0.0
# 4            0.0
# ..           ...
# 305          1.0
# 306          1.0
# 307          1.0
# 308          1.0
# 309          NaN
#
# [310 rows x 16 columns]

# %%
import matplotlib.pyplot as plt
x=d['AGE']
y=d['LUNG_CANCER']

# %%
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
x1=d['SMOKING']
y=d['LUNG_CANCER']

# %%
plt.plot(x1,y)

# %%
import matplotlib.pyplot as plt
x2=d['YELLOW_FINGERS']
y=d['LUNG_CANCER']

# %%
plt.plot(x2,y)

# %%
import matplotlib.pyplot as plt
x3=d['ANXIETY']
y=d['LUNG_CANCER']

# %%
plt.plot(x3,y)

# %%
import matplotlib.pyplot as plt
x4=d['PEER_PRESSURE']
y=d['LUNG_CANCER']

# %%
plt.plot(x4,y)

# %%
import matplotlib.pyplot as plt
x5=d['CHRONIC DISEASE']
y=d['LUNG_CANCER']

# %%
plt.plot(x5,y)
print(d.isna())
# Out:
#      GENDER    AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0     False  False    False           False    False          False
# 1     False  False    False           False    False          False
# 2     False  False    False           False    False          False
# 3     False  False    False           False    False          False
# 4     False  False    False           False    False          False
# ..      ...    ...      ...             ...      ...            ...
# 305   False  False    False           False    False          False
# 306   False  False    False           False    False          False
# 307   False  False    False           False    False          False
# 308   False  False    False           False    False          False
# 309   False   True     True            True     True           True
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0              False     False     False     False              False
# 1              False     False     False     False              False
# 2              False     False     False     False              False
# 3              False     False     False     False              False
# 4              False     False     False     False              False
# ..               ...       ...       ...       ...                ...
# 305            False     False     False     False              False
# 306            False     False     False     False              False
# 307            False     False     False     False              False
# 308            False     False     False     False              False
# 309             True      True      True      True               True
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0       False                False                  False       False
# 1       False                False                  False       False
# 2       False                False                  False       False
# 3       False                False                  False       False
# 4       False                False                  False       False
# ..        ...                  ...                    ...         ...
# 305     False                False                  False       False
# 306     False                False                  False       False
# 307     False                False                  False       False
# 308     False                False                  False       False
# 309      True                 True                   True        True
#
#      LUNG_CANCER
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 305        False
# 306        False
# 307        False
# 308        False
# 309         True
#
# [310 rows x 16 columns]

# %%
import matplotlib.pyplot as plt
d1=d.fillna(0)
print(d1.isna())
# Out:
#      GENDER    AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0     False  False    False           False    False          False
# 1     False  False    False           False    False          False
# 2     False  False    False           False    False          False
# 3     False  False    False           False    False          False
# 4     False  False    False           False    False          False
# ..      ...    ...      ...             ...      ...            ...
# 305   False  False    False           False    False          False
# 306   False  False    False           False    False          False
# 307   False  False    False           False    False          False
# 308   False  False    False           False    False          False
# 309   False  False    False           False    False          False
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0              False     False     False     False              False
# 1              False     False     False     False              False
# 2              False     False     False     False              False
# 3              False     False     False     False              False
# 4              False     False     False     False              False
# ..               ...       ...       ...       ...                ...
# 305            False     False     False     False              False
# 306            False     False     False     False              False
# 307            False     False     False     False              False
# 308            False     False     False     False              False
# 309            False     False     False     False              False
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0       False                False                  False       False
# 1       False                False                  False       False
# 2       False                False                  False       False
# 3       False                False                  False       False
# 4       False                False                  False       False
# ..        ...                  ...                    ...         ...
# 305     False                False                  False       False
# 306     False                False                  False       False
# 307     False                False                  False       False
# 308     False                False                  False       False
# 309     False                False                  False       False
#
#      LUNG_CANCER
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 305        False
# 306        False
# 307        False
# 308        False
# 309        False
#
# [310 rows x 16 columns]

# %%
x6= d1['FATIGUE ']
y= d1['LUNG_CANCER']
plt.plot(x6,y)

# %%
import matplotlib.pyplot as plt
x7=d1['ALLERGY ']
y=d1['LUNG_CANCER']

# %%
plt.plot(x6,y)

# %%
import matplotlib.pyplot as plt
x7=d1['WHEEZING']
y=d1['LUNG_CANCER']

# %%
plt.plot(x7,y)

# %%
import matplotlib.pyplot as plt
x8=d1['ALCOHOL CONSUMING']
y=d1['LUNG_CANCER']

# %%
plt.plot(x8,y)

# %%
import matplotlib.pyplot as plt
x9=d1['COUGHING']
y=d1['LUNG_CANCER']

# %%
plt.plot(x9,y)

# %%
import matplotlib.pyplot as plt
x10=d1['SHORTNESS OF BREATH']
y=d1['LUNG_CANCER']

# %%
plt.plot(x10,y)

# %%
import matplotlib.pyplot as plt
x11=d1['SWALLOWING DIFFICULTY']
y=d1['LUNG_CANCER']

# %%
plt.plot(x11,y)

# %%
import matplotlib.pyplot as plt
x12=d1['CHEST PAIN']
y=d1['LUNG_CANCER']

# %%
plt.plot(x12,y)
